# %% [markdown]
# # 4.7. Selecting the best approaches and real world applications

# %% [markdown]
# ## Pacman environment exploration

# %%
import gym # pip install gym, pip install gym[atari]
from IPython import display
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

env = gym.make('MsPacman-v0')
_ = env.reset()

# %%
print('Observation Spec:')
print(env.observation_space)

print('Reward Spec:')
print(env.reward_range)

print('Action Spec:')
print(env.action_space)

# read more: https://github.com/tensorflow/agents/blob/master/docs/tutorials/1_dqn_tutorial.ipynb
# Out:
# Observation Spec:
# Box(210, 160, 3)
# Reward Spec:
# (-inf, inf)
# Action Spec:
# Discrete(9)

# %% [markdown]
# ## Easy Agents

# %%
from easyagents.agents import DqnAgent # pip install easyagents, [pip uninstall -y enum34]
from easyagents.agents import PpoAgent
from easyagents.agents import EasyAgent
from easyagents.callbacks import plot

# %%
ppoAgent = DqnAgent('MsPacman-ram-v0', fc_layers=(200, 55))
ppoAgent.train([plot.State(), plot.Loss(), plot.Actions(), plot.Rewards()], 
               num_iterations=4000, num_iterations_between_eval=10)

# %%
ppoAgent.play([plot.State(), plot.Actions(), plot.StepRewards()], 
              num_episodes=5, 
              max_steps_per_episode=1000)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-46-bae37cc00320> in <module>
#       1 ppoAgent.play([plot.State(), plot.Actions(), plot.StepRewards()],
#       2               num_episodes=5,
# ----> 3               max_steps_per_episode=1000)
#
# ~/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/easyagents/agents.py in play(self, callbacks, num_episodes, max_steps_per_episode, play_context, default_plots)
#     294         callbacks = self._to_callback_list(callbacks=callbacks)
#     295         callbacks = self._add_plot_callbacks(callbacks, default_plots, [plot.Steps(), plot.Rewards()])
# --> 296         self._backend_agent.play(play_context=play_context, callbacks=callbacks)
#     297         return play_context
#     298
#
# ~/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/easyagents/backends/core.py in play(self, play_context, callbacks)
# ...
